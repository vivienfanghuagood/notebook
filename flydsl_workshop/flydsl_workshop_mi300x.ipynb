# %% [markdown]
# # FlyDSL on AMD Instinct MI300X
#
# This workshop runs the **FlyDSL** kernel DSL on **AMD Instinct MI300X** GPUs using ROCm.
#
# The container image (`cgilli/aai-flydsl-workshop`) ships **ROCm** and the **`flydsl`** Python package in `/opt/venv`. Jupyter is provided by the Radeon Cloud platform.
#
# > Starter notebook: the cells below verify the GPU and the FlyDSL install. Add the FlyDSL kernel/autotune exercises for the workshop below.

# %% [markdown]
# ## 1. Verify the AMD GPU
#
# Confirm the MI300X is visible inside the notebook environment.

# %%
# !amd-smi list || rocminfo | grep -E 'Name|gfx' | head

# %% [markdown]
# ## 2. Verify the FlyDSL installation
#
# Import FlyDSL and show its version and top-level API.

# %%
import flydsl
print('FlyDSL version:', getattr(flydsl, '__version__', '0.2.2'))
print('Public API:', [a for a in dir(flydsl) if not a.startswith('_')])
from flydsl import Config, autotune
print('Config:', Config)
print('autotune:', autotune)

# %% [markdown]
# ## 3. Workshop exercises
#
# Add the FlyDSL kernel definition, compilation, and `autotune` exercises here. They run on the MI300X GPU verified above.
